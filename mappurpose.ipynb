# %%
import pandas as pd
import folium
from pandas.io import sql 
import MySQLdb

con = MySQLdb.connect(user='root', password='',host='localhost', database='website_myflood')
cursor.execute =("select CurrentWaterLevel from selangor-scrape where StationID = 3217435 "
# df = pd.read_csv("latlong.csv", names=['statid','lat','long']) 
# df.dropna(inplace=True)
# df2 = pd.read_csv("latlongsel.csv", names=['statid','lat','long']) 
# df2.dropna(inplace=True)

# m = folium.Map(location=[3.1067998,101.6087607], tiles="OpenStreetMap", zoom_start=10)

# for i in range(0,len(df)):
#    folium.Marker(location=[df.iloc[i]['lat'], df.iloc[i]['long']],).add_to(m)
#    print(df['statid'][i])
    

# # for i in range(0,len(df2)):
# #    folium.Marker(location=[df2.iloc[i]['lat'], df2.iloc[i]['long']],).add_to(m)

# m

# %%
from pandas.io import sql 
import MySQLdb
con = MySQLdb.connect(user='root', password='',host='localhost', database='website_myflood')
concursor = con.cursor()
i = 3217435
x = i
state = ("SELECT CurrentWaterLevel FROM `selangor-scrape` WHERE `Station ID` = %(x)s")
concursor.execute(state, {'x': x })
#concursor.execute("SELECT CurrentWaterLevel := `")
result = concursor.fetchall()
print(result)

# %%
import pandas as pd
import folium
from pandas.io import sql 
import MySQLdb

con = MySQLdb.connect(user='root', password='',host='localhost', database='website_myflood')
concursor = con.cursor()

df = pd.read_csv("latlong.csv", names=['statid','lat','long']) 
df.dropna(inplace=True)

df2 = pd.read_csv("latlongsel.csv", names=['statid','lat','long']) 
df2.dropna(inplace=True)

m = folium.Map(location=[3.1067998,101.6087607], tiles="OpenStreetMap", zoom_start=10)

for i in range(0,len(df)):
   
   #print(df['statid'][i])
   x = df['statid'][i]
   state = ("SELECT CurrentWaterLevel FROM `selangor-scrape` WHERE `Station ID` = %(x)s")
   concursor.execute(state, {'x': x })
   result = concursor.fetchall()
   print(result)
   name = df['statid'][i]
   state = ("SELECT `Station Name` FROM `selangor-scrape` WHERE `Station ID` = %(name)s")
   concursor.execute(state, {'name': name })
   result2 = concursor.fetchall()
   print(result2)
#    newformat = ("{}\n{}".format(result2,result))
#    folium.Marker(location=[df.iloc[i]['lat'], df.iloc[i]['long']]).add_to(m)

    
# m
# m.save("heat_map.html")

# %%
df['alert'] = ''
df['warning'] = ''
df['danger'] = ''

# %%
import pandas as pd
import folium
from pandas.io import sql 
import MySQLdb

con = MySQLdb.connect(user='root', password='',host='localhost', database='website_myflood')
concursor = con.cursor()

df = pd.read_csv("latlong.csv", names=['statid','lat','long']) 
df.dropna(inplace=True)
df

# %%
df.reset_index(drop=True, inplace = True)
df
# Out:
#     statid       lat        long value
# 0  3217435  3.236111  101.752778
# 1  3217403  3.245278  101.715278
# 2  3116434  3.176389  101.687500
# 3  3116433  3.173611  101.697222
# 4  3117403  3.169722  101.713333
# 5  3116439  3.151333  101.695306
# 6  3116435  3.150500  101.698472
# 7  3116436  3.112583  101.696583
# 8  3116430  3.138889  101.697222
# 9  3016401  3.080917  101.665194

# %%
con = MySQLdb.connect(user='root', password='',host='localhost', database='website_myflood')
concursor = con.cursor()

for i in range(0,len(df)):
   x = df['statid'][i]
   state = ("SELECT CurrentWaterLevel FROM `selangorscrape` WHERE `Station ID` = %(x)s")
   concursor.execute(state, {'x': x })
   result = concursor.fetchall()
   print(result)
   df['value'][i] = result
for i in range(0,len(df)):
   x = df['statid'][i]
   state = ("SELECT Alert FROM `selangorscrape` WHERE `Station ID` = %(x)s")
   concursor.execute(state, {'x': x })
   result = concursor.fetchall()
   print(result)
   df['alert'][i] = result
for i in range(0,len(df)):
   x = df['statid'][i]
   state = ("SELECT Warning FROM `selangorscrape` WHERE `Station ID` = %(x)s")
   concursor.execute(state, {'x': x })
   result = concursor.fetchall()
   print(result)
   df['warning'][i] = result
for i in range(0,len(df)):
   x = df['statid'][i]
   state = ("SELECT Danger FROM `selangorscrape` WHERE `Station ID` = %(x)s")
   concursor.execute(state, {'x': x })
   result = concursor.fetchall()
   print(result)
   df['danger'][i] = result
# Out:
# ((93.21,),)
# ((57.55,),)
# ((29.51,),)
# ((28.19,),)
# ((30.75,),)
# ((24.96,),)
# ((25.11,),)
# ((23.68,),)
# ((22.47,),)
# ((12.95,),)
# ((96.5,),)
# ((60.0,),)
# ((32.0,),)
# ((30.0,),)
# ((35.0,),)
# ((29.0,),)
# ((28.0,),)
# ((28.0,),)
# ((27.0,),)
# ((17.0,),)
# ((96.65,),)
# ((61.0,),)
# ((32.3,),)
# ((30.5,),)
# ((35.5,),)
# ((30.0,),)
# ((29.0,),)
# ((29.0,),)
# ((28.25,),)
# ((18.0,),)
# ((97.0,),)
# ((62.0,),)
# ((33.0,),)
# ((31.0,),)
# ((36.0,),)
# ((31.0,),)
# ((30.0,),)
# ((30.0,),)
# ((29.5,),)
# ((19.0,),)
# C:\Users\Asus\AppData\Local\Temp\ipykernel_54696\3582417952.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['value'][i] = result
# C:\Users\Asus\AppData\Local\Temp\ipykernel_54696\3582417952.py:17: SettingWithCopyWarning:
# ...

# %%
df
# Out:
#     statid       lat        long  value alert warning danger
# 0  3217435  3.236111  101.752778  93.21  96.5   96.65   97.0
# 1  3217403  3.245278  101.715278  57.55  60.0    61.0   62.0
# 2  3116434  3.176389  101.687500  29.51  32.0    32.3   33.0
# 3  3116433  3.173611  101.697222  28.19  30.0    30.5   31.0
# 4  3117403  3.169722  101.713333  30.75  35.0    35.5   36.0
# 5  3116439  3.151333  101.695306  24.96  29.0    30.0   31.0
# 6  3116435  3.150500  101.698472  25.11  28.0    29.0   30.0
# 7  3116436  3.112583  101.696583  23.68  28.0    29.0   30.0
# 8  3116430  3.138889  101.697222  22.47  27.0   28.25   29.5
# 9  3016401  3.080917  101.665194  12.95  17.0    18.0   19.0

# %%
df
df['value'] = df['value'].astype(str).str.replace(r'\(|\)|,|,', '')
df['alert'] = df['alert'].astype(str).str.replace(r'\(|\)|,|,', '')
df['warning'] = df['warning'].astype(str).str.replace(r'\(|\)|,|,', '')
df['danger'] = df['danger'].astype(str).str.replace(r'\(|\)|,|,', '')
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_54696\107229572.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['value'] = df['value'].astype(str).str.replace(r'\(|\)|,|,', '')
# C:\Users\Asus\AppData\Local\Temp\ipykernel_54696\107229572.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['alert'] = df['alert'].astype(str).str.replace(r'\(|\)|,|,', '')
# C:\Users\Asus\AppData\Local\Temp\ipykernel_54696\107229572.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['warning'] = df['warning'].astype(str).str.replace(r'\(|\)|,|,', '')
# C:\Users\Asus\AppData\Local\Temp\ipykernel_54696\107229572.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['danger'] = df['danger'].astype(str).str.replace(r'\(|\)|,|,', '')

# %%
from sqlalchemy import create_engine

df
con = MySQLdb.connect(user='root', password='',host='localhost', database='website_myflood')
engine = create_engine("mysql+pymysql://root:@localhost/website_myflood")
df.to_sql('tomap', con = engine, if_exists='replace')

# %%
df
df = df[['lat', 'long', 'value', 'statid']]

# %%
df['icon'] = ('images/3.png')

# %%
df
df.rename(columns = {'lat':'latitude','long':'longitude'}, inplace = True)# In[ ]:
df.rename(columns = {'value':'name','statid':'info'}, inplace = True)# In[ ]:def test_get_all_by_host_with_pool(self):

# %%
from sqlalchemy import create_engine

df
con = MySQLdb.connect(user='root', password='',host='localhost', database='website_myflood')
engine = create_engine("mysql+pymysql://root:@localhost/website_myflood")
df.to_sql('tomap', con = engine, if_exists='append')

# %%
df

# %%
from sqlalchemy import create_engine


con = MySQLdb.connect(user='root', password='',host='localhost', database='website_myflood')
engine = create_engine("mysql+pymysql://root:@localhost/website_myflood")
df.to_sql('locations', con = engine, if_exists='append',index=False)

# %%
import pandas as pd
import folium
from pandas.io import sql 
import MySQLdb

con = MySQLdb.connect(user='root', password='',host='localhost', database='website_myflood')
concursor = con.cursor()

df = pd.read_csv("latlong.csv", names=['statid','lat','long']) 
df.dropna(inplace=True)
df
# Out:
#     statid       lat        long
# 0  3217435  3.236111  101.752778
# 1  3217403  3.245278  101.715278
# 2  3116434  3.176389  101.687500
# 3  3116433  3.173611  101.697222
# 4  3117403  3.169722  101.713333
# 5  3116439  3.151333  101.695306
# 6  3116435  3.150500  101.698472
# 7  3116436  3.112583  101.696583
# 8  3116430  3.138889  101.697222
# 9  3016401  3.080917  101.665194

# %%
df

# %%
df
df.rename(columns = {'lat':'latitude','long':'longitude'}, inplace = True)# In[ ]:
df.rename(columns = {'value':'name','statid':'info'}, inplace = True)# In[ ]:def test_get_all_by_host_with_pool(self):

# %%
df

# %%
df = df[['latitude', 'longitude', 'name', 'info','icon']]

# %%
df

# %%
from sqlalchemy import create_engine


con = MySQLdb.connect(user='root', password='',host='localhost', database='website_myflood')
engine = create_engine("mysql+pymysql://root:@localhost/website_myflood")
df.to_sql('locations', con = engine, if_exists='append',index=False)

# %%
df
df['smsAlert'] = ''
df

# %%
for i in range(0,len(df)):
   x = df['statid'][i]
   state = ("SELECT smsAlert FROM `selangorscrape` WHERE `Station ID` = %(x)s")
   concursor.execute(state, {'x': x })
   result = concursor.fetchall()
   print(result)
   df['yapbobo1'][i] = result

# %%
df['smsAlert'] = df['smsAlert'].astype(str).str.replace(r'\(|\)|,|,', '')

# %%
df['smsAlert'] = df['smsAlert'].astype(str).str.replace(r'\(|\'\'\)|,|,', '')

# %%
df

# %%
df

# %%
df['smsAlert'] = df2['smsAlert'].astype(str).str.replace(r'\(|\)|''|,|,','')

# %%
df2['smsAlert'] = df2['smsAlert'].astype(str).str.replace(r'\(|\\)|,|,', '')

# %%
df2 = df

# %%
df2['smsAlert'] = df2['smsAlert'].astype(str).str.replace(r'\(|\)|''|''\|,|,','')

# %%
df2

# %%
df2['smsAlert'] = df2['smsAlert'].astype(str).str.replace(r'\(\'|''\)|,|,','')

# %%
df2['smsAlert'] = df2['smsAlert'].astype("string")

# %%
df2.dtypes

# %%
df2['smsAlert'] = df2['smsAlert'].str.replace(r'"', '')

# %%
df2['smsAlert'].replace(regex=True,inplace=False,to_replace=r'"',value=r'')

# %%
df2

# %%
import numpy as np 
df2['newtesting2'] = np.where(df2['smsAlert']>df2['newtesting'], 'yes', 'no')

# %%
df2['yapbobo1'] = '((nosms,),)'

# %%
df2

# %%
df2

# %%
import numpy as np 
df2['comparison'] = np.where(df2['newnewnew']==df2['yapbobo1'], 'yes', 'no')

# %%
df2

# %%
df
# Out:
#     statid       lat        long  value alert warning danger
# 0  3217435  3.236111  101.752778  93.21  96.5   96.65   97.0
# 1  3217403  3.245278  101.715278  57.55  60.0    61.0   62.0
# 2  3116434  3.176389  101.687500  29.51  32.0    32.3   33.0
# 3  3116433  3.173611  101.697222  28.19  30.0    30.5   31.0
# 4  3117403  3.169722  101.713333  30.75  35.0    35.5   36.0
# 5  3116439  3.151333  101.695306  24.96  29.0    30.0   31.0
# 6  3116435  3.150500  101.698472  25.11  28.0    29.0   30.0
# 7  3116436  3.112583  101.696583  23.68  28.0    29.0   30.0
# 8  3116430  3.138889  101.697222  22.47  27.0   28.25   29.5
# 9  3016401  3.080917  101.665194  12.95  17.0    18.0   19.0

# %%
compare = []
for i in range(0,len(df)):
    if df['value'][i] < df['alert'][i]:
        compare.append("Normal")
    elif df['value'] >= df['alert']:
        compare.append("Alert")
    elif df['value'] >= df['warning']:
        compare.append("Warning")
    elif df['value'] >= df['danger']:
        compare.append("Danger")


df['Danger Level'] = compare

# %%
df.dtypes
# Out:
# statid       int64
# lat        float64
# long       float64
# value      float64
# alert      float64
# warning    float64
# danger     float64
# dtype: object

# %%
df = df.astype({"value": float, "alert": float, "warning":float, "danger":float})

# %%
df
# Out:
#     statid       lat        long  value  alert  warning  danger
# 0  3217435  3.236111  101.752778  93.21   96.5    96.65    97.0
# 1  3217403  3.245278  101.715278  57.55   60.0    61.00    62.0
# 2  3116434  3.176389  101.687500  29.51   32.0    32.30    33.0
# 3  3116433  3.173611  101.697222  28.19   30.0    30.50    31.0
# 4  3117403  3.169722  101.713333  30.75   35.0    35.50    36.0
# 5  3116439  3.151333  101.695306  24.96   29.0    30.00    31.0
# 6  3116435  3.150500  101.698472  25.11   28.0    29.00    30.0
# 7  3116436  3.112583  101.696583  23.68   28.0    29.00    30.0
# 8  3116430  3.138889  101.697222  22.47   27.0    28.25    29.5
# 9  3016401  3.080917  101.665194  12.95   17.0    18.00    19.0

# %%
df
# Out:
#     statid       lat        long  value  alert  warning  danger Danger Level
# 0  3217435  3.236111  101.752778  93.21   96.5    96.65    97.0       Normal
# 1  3217403  3.245278  101.715278  57.55   60.0    61.00    62.0       Normal
# 2  3116434  3.176389  101.687500  29.51   32.0    32.30    33.0       Normal
# 3  3116433  3.173611  101.697222  28.19   30.0    30.50    31.0       Normal
# 4  3117403  3.169722  101.713333  30.75   35.0    35.50    36.0       Normal
# 5  3116439  3.151333  101.695306  24.96   29.0    30.00    31.0       Normal
# 6  3116435  3.150500  101.698472  25.11   28.0    29.00    30.0       Normal
# 7  3116436  3.112583  101.696583  23.68   28.0    29.00    30.0       Normal
# 8  3116430  3.138889  101.697222  22.47   27.0    28.25    29.5       Normal
# 9  3016401  3.080917  101.665194  12.95   17.0    18.00    19.0       Normal

# %%
df
# Out:
#     statid       lat        long  value  alert  warning  danger Danger Level
# 0  3217435  3.236111  101.752778  93.21   96.5    96.65    97.0       Normal
# 1  3217403  3.245278  101.715278  57.55   60.0    61.00    62.0       Normal
# 2  3116434  3.176389  101.687500  29.51   32.0    32.30    33.0       Normal
# 3  3116433  3.173611  101.697222  28.19   30.0    30.50    31.0       Normal
# 4  3117403  3.169722  101.713333  30.75   35.0    35.50    36.0       Normal
# 5  3116439  3.151333  101.695306  24.96   29.0    30.00    31.0       Normal
# 6  3116435  3.150500  101.698472  25.11   28.0    29.00    30.0       Normal
# 7  3116436  3.112583  101.696583  23.68   28.0    29.00    30.0       Normal
# 8  3116430  3.138889  101.697222  22.47   27.0    28.25    29.5       Normal
# 9  3016401  3.080917  101.665194  12.95   17.0    18.00    19.0       Normal

# %%
df['value'] = df['value'].replace('93.21', '98.0')

# %%
df
# Out:
#     statid       lat        long  value  alert  warning  danger Danger Level
# 0  3217435  3.236111  101.752778  93.21   96.5    96.65    97.0       Normal
# 1  3217403  3.245278  101.715278  57.55   60.0    61.00    62.0       Normal
# 2  3116434  3.176389  101.687500  29.51   32.0    32.30    33.0       Normal
# 3  3116433  3.173611  101.697222  28.19   30.0    30.50    31.0       Normal
# 4  3117403  3.169722  101.713333  30.75   35.0    35.50    36.0       Normal
# 5  3116439  3.151333  101.695306  24.96   29.0    30.00    31.0       Normal
# 6  3116435  3.150500  101.698472  25.11   28.0    29.00    30.0       Normal
# 7  3116436  3.112583  101.696583  23.68   28.0    29.00    30.0       Normal
# 8  3116430  3.138889  101.697222  22.47   27.0    28.25    29.5       Normal
# 9  3016401  3.080917  101.665194  12.95   17.0    18.00    19.0       Normal

# %%
df['value'][0] = 98.0
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_54696\1120360420.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['value'][0] = 98.0

# %%
df
# Out:
#     statid       lat        long  value  alert  warning  danger Danger Level
# 0  3217435  3.236111  101.752778  98.00   96.5    96.65    97.0       Normal
# 1  3217403  3.245278  101.715278  57.55   60.0    61.00    62.0       Normal
# 2  3116434  3.176389  101.687500  29.51   32.0    32.30    33.0       Normal
# 3  3116433  3.173611  101.697222  28.19   30.0    30.50    31.0       Normal
# 4  3117403  3.169722  101.713333  30.75   35.0    35.50    36.0       Normal
# 5  3116439  3.151333  101.695306  24.96   29.0    30.00    31.0       Normal
# 6  3116435  3.150500  101.698472  25.11   28.0    29.00    30.0       Normal
# 7  3116436  3.112583  101.696583  23.68   28.0    29.00    30.0       Normal
# 8  3116430  3.138889  101.697222  22.47   27.0    28.25    29.5       Normal
# 9  3016401  3.080917  101.665194  12.95   17.0    18.00    19.0       Normal

# %%
compare = []
for i in range(0,len(df)):
    if df['value'][i] > df['danger'][i]:
        compare.append("http://maps.google.com/mapfiles/ms/icons/red-dot.png")
    elif df['value'][i] > df['warning'][i]:
        compare.append("http://maps.google.com/mapfiles/ms/icons/yellow-dot.png")
    elif df['value'][i] > df['alert'][i]:
        compare.append("http://maps.google.com/mapfiles/ms/icons/blue-dot.png")
    elif df['value'][i] < df['alert'][i]:
        compare.append("http://maps.google.com/mapfiles/ms/icons/green-dot.png")
df['Danger Level'] = compare

# %%
df
# Out:
#     statid       lat        long  value  alert  warning  danger  \
# 0  3217435  3.236111  101.752778  98.00   96.5    96.65    97.0
# 1  3217403  3.245278  101.715278  57.55   60.0    61.00    62.0
# 2  3116434  3.176389  101.687500  29.51   32.0    32.30    33.0
# 3  3116433  3.173611  101.697222  28.19   30.0    30.50    31.0
# 4  3117403  3.169722  101.713333  30.75   35.0    35.50    36.0
# 5  3116439  3.151333  101.695306  24.96   29.0    30.00    31.0
# 6  3116435  3.150500  101.698472  25.11   28.0    29.00    30.0
# 7  3116436  3.112583  101.696583  23.68   28.0    29.00    30.0
# 8  3116430  3.138889  101.697222  22.47   27.0    28.25    29.5
# 9  3016401  3.080917  101.665194  12.95   17.0    18.00    19.0
#
#                                         Danger Level
# 0  http://maps.google.com/mapfiles/ms/icons/red-d...
# 1  http://maps.google.com/mapfiles/ms/icons/green...
# 2  http://maps.google.com/mapfiles/ms/icons/green...
# ...

# %%
df
df = df[['lat', 'long', 'value', 'statid','Danger Level','alert','warning','danger']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [70], in <cell line: 2>()
#       1 df
# ----> 2 df = df[['lat', 'long', 'value', 'statid','Danger Level','alert','warning','danger']]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
#    5780     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5782 self._raise_if_missing(keyarr, indexer, axis_name)
# ...

# %%
df
df.rename(columns = {'lat':'latitude','long':'longitude','value':'name','statid':'info'}, inplace = True)# In[ ]:

# %%
df
# Out:
#    latitude   longitude   name     info  alert  \
# 0  3.236111  101.752778  98.00  3217435   96.5
# 1  3.245278  101.715278  57.55  3217403   60.0
# 2  3.176389  101.687500  29.51  3116434   32.0
# 3  3.173611  101.697222  28.19  3116433   30.0
# 4  3.169722  101.713333  30.75  3117403   35.0
# 5  3.151333  101.695306  24.96  3116439   29.0
# 6  3.150500  101.698472  25.11  3116435   28.0
# 7  3.112583  101.696583  23.68  3116436   28.0
# 8  3.138889  101.697222  22.47  3116430   27.0
# 9  3.080917  101.665194  12.95  3016401   17.0
#
#                                         Danger Level  warning  danger
# 0  http://maps.google.com/mapfiles/ms/icons/red-d...    96.65    97.0
# 1  http://maps.google.com/mapfiles/ms/icons/green...    61.00    62.0
# 2  http://maps.google.com/mapfiles/ms/icons/green...    32.30    33.0
# 3  http://maps.google.com/mapfiles/ms/icons/green...    30.50    31.0
# 4  http://maps.google.com/mapfiles/ms/icons/green...    35.50    36.0
# ...

# %%
df.rename(columns = {'Danger Level':'icon'},inplace = True)
df
# Out:
#    latitude   longitude   name     info  \
# 0  3.236111  101.752778  98.00  3217435
# 1  3.245278  101.715278  57.55  3217403
# 2  3.176389  101.687500  29.51  3116434
# 3  3.173611  101.697222  28.19  3116433
# 4  3.169722  101.713333  30.75  3117403
# 5  3.151333  101.695306  24.96  3116439
# 6  3.150500  101.698472  25.11  3116435
# 7  3.112583  101.696583  23.68  3116436
# 8  3.138889  101.697222  22.47  3116430
# 9  3.080917  101.665194  12.95  3016401
#
#                                                 icon  alert  warning  danger
# 0  http://maps.google.com/mapfiles/ms/icons/red-d...   96.5    96.65    97.0
# 1  http://maps.google.com/mapfiles/ms/icons/green...   60.0    61.00    62.0
# 2  http://maps.google.com/mapfiles/ms/icons/green...   32.0    32.30    33.0
# 3  http://maps.google.com/mapfiles/ms/icons/green...   30.0    30.50    31.0
# 4  http://maps.google.com/mapfiles/ms/icons/green...   35.0    35.50    36.0
# ...

# %%
from sqlalchemy import create_engine


con = MySQLdb.connect(user='root', password='',host='localhost', database='website_myflood')
engine = create_engine("mysql+pymysql://root:@localhost/website_myflood")
df.to_sql('locations', con = engine, if_exists='append',index=False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\engine\base.py:1880, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1879     if not evt_handled:
# -> 1880         self.dialect.do_executemany(
#    1881             cursor, statement, parameters, context
#    1882         )
#    1883 elif not parameters and context.no_parameters:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py:193, in MySQLDialect_mysqldb.do_executemany(self, cursor, statement, parameters, context)
#     192 def do_executemany(self, cursor, statement, parameters, context=None):
# --> 193     rowcount = cursor.executemany(statement, parameters)
#     194     if context is not None:
#
# ...

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df2 = df[['latitude','longitude','name','info','icon']]

# %%
df2
# Out:
#    latitude   longitude   name     info  \
# 0  3.236111  101.752778  98.00  3217435
# 1  3.245278  101.715278  57.55  3217403
# 2  3.176389  101.687500  29.51  3116434
# 3  3.173611  101.697222  28.19  3116433
# 4  3.169722  101.713333  30.75  3117403
# 5  3.151333  101.695306  24.96  3116439
# 6  3.150500  101.698472  25.11  3116435
# 7  3.112583  101.696583  23.68  3116436
# 8  3.138889  101.697222  22.47  3116430
# 9  3.080917  101.665194  12.95  3016401
#
#                                                 icon
# 0  http://maps.google.com/mapfiles/ms/icons/red-d...
# 1  http://maps.google.com/mapfiles/ms/icons/green...
# 2  http://maps.google.com/mapfiles/ms/icons/green...
# 3  http://maps.google.com/mapfiles/ms/icons/green...
# 4  http://maps.google.com/mapfiles/ms/icons/green...
# 5  http://maps.google.com/mapfiles/ms/icons/green...
# 6  http://maps.google.com/mapfiles/ms/icons/green...
# 7  http://maps.google.com/mapfiles/ms/icons/green...
# ...

# %%
from sqlalchemy import create_engine


con = MySQLdb.connect(user='root', password='',host='localhost', database='website_myflood')
engine = create_engine("mysql+pymysql://root:@localhost/website_myflood")
df2.to_sql('locations', con = engine, if_exists='append',index=False)
# Out:
# 10
