# %%
import pandas as pd
import folium
from pandas.io import sql 
import MySQLdb

con = MySQLdb.connect(user='root', password='',host='localhost', database='website_myflood')
concursor = con.cursor()

df = pd.read_csv("latlongnewcombined.csv", names=['statid','lat','long']) 
df.dropna(inplace=True)
df
# Out:
#      statid       lat        long
# 0   3516424  3.541417  101.662333
# 1   3416403  3.469917  101.639806
# 2   3808401  3.856556  100.895833
# 3   3414421  3.402778  101.443056
# 4   3313445  3.371917  101.370500
# 5   3312446  3.342528  101.269111
# 6   3214401  3.246139  101.469694
# 7   3313470  3.306722  101.386444
# 8   3315401  3.304694  101.591944
# 9   3017445  3.014500  101.718667
# 10  3016402  3.096528  101.634389
# 11  3015436  3.019528  101.597417
# 12  3115403  3.112278  101.596444
# 13  3115404  3.150056  101.540944
# 14  3015490  3.096944  101.554167
# 15  3015435  3.075611  101.553889
# 16  3015432  3.037722  101.534500
# 17  3014401  3.048056  101.444806
# 18  3218401  3.209639  101.875861
# 19  2917401  2.994444  101.786111
# 20  3018401  3.013444  101.866056
# 21  2918401  2.915278  101.823611
# 22  2717401  2.788667  101.741972
# 23  2816441  2.992778  101.786944
# 24  2816443  2.813472  101.641917

# %%
df['value'] = ''
df['alert'] = ''
df['warning'] = ''
df['danger'] = ''

# %%
con = MySQLdb.connect(user='root', password='',host='localhost', database='website_myflood')
concursor = con.cursor()

for i in range(0,len(df)):
   x = df['statid'][i]
   state = ("SELECT CurrentWaterLevel FROM `selangorscrape` WHERE `Station ID` = %(x)s")
   concursor.execute(state, {'x': x })
   result = concursor.fetchall()
   print(result)
   df['value'][i] = result
for i in range(0,len(df)):
   x = df['statid'][i]
   state = ("SELECT Alert FROM `selangorscrape` WHERE `Station ID` = %(x)s")
   concursor.execute(state, {'x': x })
   result = concursor.fetchall()
   print(result)
   df['alert'][i] = result
for i in range(0,len(df)):
   x = df['statid'][i]
   state = ("SELECT Warning FROM `selangorscrape` WHERE `Station ID` = %(x)s")
   concursor.execute(state, {'x': x })
   result = concursor.fetchall()
   print(result)
   df['warning'][i] = result
for i in range(0,len(df)):
   x = df['statid'][i]
   state = ("SELECT Danger FROM `selangorscrape` WHERE `Station ID` = %(x)s")
   concursor.execute(state, {'x': x })
   result = concursor.fetchall()
   print(result)
   df['danger'][i] = result
# Out:
# ((50.49,),)
# C:\Users\Asus\AppData\Local\Temp\ipykernel_33152\3582417952.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['value'][i] = result
# C:\Users\Asus\AppData\Local\Temp\ipykernel_33152\3582417952.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['alert'][i] = result
# ((32.5,),)
# ((0.26,),)
# ((6.1,),)
# ((2.08,),)
# ((2.02,),)
# ((4.53,),)
# ((3.06,),)
# ((33.07,),)
# ((36.34,),)
# ((17.03,),)
# ((5.27,),)
# ((14.73,),)
# ((15.18,),)
# ((0.15,),)
# ((2.64,),)
# ((2.84,),)
# ((2.13,),)
# ((131.65,),)
# ((22.47,),)
# ((48.41,),)
# ((20.71,),)
# ((6.96,),)
# ((4.13,),)
# ((2.6,),)
# ((51.3,),)
# ((35.2,),)
# ((4.3,),)
# ((6.8,),)
# ((3.22,),)
# ((2.1,),)
# ((6.5,),)
# ((3.5,),)
# ((34.3,),)
# ((38.5,),)
# ((21.0,),)
# ((9.0,),)
# ((17.0,),)
# ((16.4,),)
# ((7.3,),)
# ((4.5,),)
# ((4.4,),)
# ((2.4,),)
# ((133.4,),)
# ((24.4,),)
# ((48.8,),)
# ((24.0,),)
# ((8.2,),)
# ((6.4,),)
# ((3.3,),)
# ((51.6,),)
# ((35.5,),)
# ((4.6,),)
# ((7.3,),)
# ((3.38,),)
# ((2.6,),)
# ((7.0,),)
# ((4.0,),)
# ((34.8,),)
# ((39.0,),)
# ((21.5,),)
# ((9.5,),)
# ((17.5,),)
# ((16.9,),)
# ((7.8,),)
# ((5.0,),)
# ((4.7,),)
# ((2.7,),)
# ((133.9,),)
# ((25.4,),)
# ((49.8,),)
# ((24.5,),)
# ((8.7,),)
# ((6.9,),)
# ((3.8,),)
# ((51.9,),)
# ((35.8,),)
# ((4.9,),)
# ((7.8,),)
# ((3.54,),)
# ((3.1,),)
# ((7.5,),)
# C:\Users\Asus\AppData\Local\Temp\ipykernel_33152\3582417952.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['warning'][i] = result
# C:\Users\Asus\AppData\Local\Temp\ipykernel_33152\3582417952.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['danger'][i] = result
# ((4.5,),)
# ((35.3,),)
# ((40.0,),)
# ((22.0,),)
# ((10.0,),)
# ((18.0,),)
# ((17.4,),)
# ((8.3,),)
# ((6.0,),)
# ((5.0,),)
# ((3.0,),)
# ((134.4,),)
# ((26.4,),)
# ((50.3,),)
# ((25.6,),)
# ((9.2,),)
# ((7.5,),)
# ((4.2,),)

# %%
df
# Out:
#      statid       lat        long         value        alert      warning  \
# 0   3516424  3.541417  101.662333   ((50.49,),)   ((51.3,),)   ((51.6,),)
# 1   3416403  3.469917  101.639806    ((32.5,),)   ((35.2,),)   ((35.5,),)
# 2   3808401  3.856556  100.895833    ((0.26,),)    ((4.3,),)    ((4.6,),)
# 3   3414421  3.402778  101.443056     ((6.1,),)    ((6.8,),)    ((7.3,),)
# 4   3313445  3.371917  101.370500    ((2.08,),)   ((3.22,),)   ((3.38,),)
# 5   3312446  3.342528  101.269111    ((2.02,),)    ((2.1,),)    ((2.6,),)
# 6   3214401  3.246139  101.469694    ((4.53,),)    ((6.5,),)    ((7.0,),)
# 7   3313470  3.306722  101.386444    ((3.06,),)    ((3.5,),)    ((4.0,),)
# 8   3315401  3.304694  101.591944   ((33.07,),)   ((34.3,),)   ((34.8,),)
# 9   3017445  3.014500  101.718667   ((36.34,),)   ((38.5,),)   ((39.0,),)
# 10  3016402  3.096528  101.634389   ((17.03,),)   ((21.0,),)   ((21.5,),)
# 11  3015436  3.019528  101.597417    ((5.27,),)    ((9.0,),)    ((9.5,),)
# 12  3115403  3.112278  101.596444   ((14.73,),)   ((17.0,),)   ((17.5,),)
# 13  3115404  3.150056  101.540944   ((15.18,),)   ((16.4,),)   ((16.9,),)
# 14  3015490  3.096944  101.554167    ((0.15,),)    ((7.3,),)    ((7.8,),)
# 15  3015435  3.075611  101.553889    ((2.64,),)    ((4.5,),)    ((5.0,),)
# 16  3015432  3.037722  101.534500    ((2.84,),)    ((4.4,),)    ((4.7,),)
# 17  3014401  3.048056  101.444806    ((2.13,),)    ((2.4,),)    ((2.7,),)
# 18  3218401  3.209639  101.875861  ((131.65,),)  ((133.4,),)  ((133.9,),)
# 19  2917401  2.994444  101.786111   ((22.47,),)   ((24.4,),)   ((25.4,),)
# 20  3018401  3.013444  101.866056   ((48.41,),)   ((48.8,),)   ((49.8,),)
# 21  2918401  2.915278  101.823611   ((20.71,),)   ((24.0,),)   ((24.5,),)
# 22  2717401  2.788667  101.741972    ((6.96,),)    ((8.2,),)    ((8.7,),)
# 23  2816441  2.992778  101.786944    ((4.13,),)    ((6.4,),)    ((6.9,),)
# 24  2816443  2.813472  101.641917     ((2.6,),)    ((3.3,),)    ((3.8,),)
#
#          danger
# 0    ((51.9,),)
# 1    ((35.8,),)
# 2     ((4.9,),)
# 3     ((7.8,),)
# 4    ((3.54,),)
# 5     ((3.1,),)
# 6     ((7.5,),)
# 7     ((4.5,),)
# 8    ((35.3,),)
# 9    ((40.0,),)
# 10   ((22.0,),)
# 11   ((10.0,),)
# 12   ((18.0,),)
# 13   ((17.4,),)
# 14    ((8.3,),)
# 15    ((6.0,),)
# 16    ((5.0,),)
# 17    ((3.0,),)
# 18  ((134.4,),)
# 19   ((26.4,),)
# 20   ((50.3,),)
# 21   ((25.6,),)
# 22    ((9.2,),)
# 23    ((7.5,),)
# 24    ((4.2,),)

# %%
df['value'] = df['value'].astype(str).str.replace(r'\(|\)|,|,', '')
df['alert'] = df['alert'].astype(str).str.replace(r'\(|\)|,|,', '')
df['warning'] = df['warning'].astype(str).str.replace(r'\(|\)|,|,', '')
df['danger'] = df['danger'].astype(str).str.replace(r'\(|\)|,|,', '')
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_33152\189248526.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['value'] = df['value'].astype(str).str.replace(r'\(|\)|,|,', '')
# C:\Users\Asus\AppData\Local\Temp\ipykernel_33152\189248526.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['alert'] = df['alert'].astype(str).str.replace(r'\(|\)|,|,', '')
# C:\Users\Asus\AppData\Local\Temp\ipykernel_33152\189248526.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['warning'] = df['warning'].astype(str).str.replace(r'\(|\)|,|,', '')
# C:\Users\Asus\AppData\Local\Temp\ipykernel_33152\189248526.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['danger'] = df['danger'].astype(str).str.replace(r'\(|\)|,|,', '')

# %%
df
df = df.astype({"value": float, "alert": float, "warning":float, "danger":float})

# %%
compare = []
for i in range(0,len(df)):
    if df['value'][i] > df['danger'][i]:
        compare.append("http://maps.google.com/mapfiles/ms/icons/red-dot.png")
    elif df['value'][i] > df['warning'][i]:
        compare.append("http://maps.google.com/mapfiles/ms/icons/yellow-dot.png")
    elif df['value'][i] > df['alert'][i]:
        compare.append("http://maps.google.com/mapfiles/ms/icons/blue-dot.png")
    elif df['value'][i] < df['alert'][i]:
        compare.append("http://maps.google.com/mapfiles/ms/icons/green-dot.png")
df['Danger Level'] = compare

# %%
df.rename(columns = {'lat':'latitude','long':'longitude','value':'name','statid':'info','Danger Level':'icon'}, inplace = True)

# %%
df
# Out:
#        info  latitude   longitude    name   alert  warning  danger  \
# 0   3516424  3.541417  101.662333   50.49   51.30    51.60   51.90
# 1   3416403  3.469917  101.639806   32.50   35.20    35.50   35.80
# 2   3808401  3.856556  100.895833    0.26    4.30     4.60    4.90
# 3   3414421  3.402778  101.443056    6.10    6.80     7.30    7.80
# 4   3313445  3.371917  101.370500    2.08    3.22     3.38    3.54
# 5   3312446  3.342528  101.269111    2.02    2.10     2.60    3.10
# 6   3214401  3.246139  101.469694    4.53    6.50     7.00    7.50
# 7   3313470  3.306722  101.386444    3.06    3.50     4.00    4.50
# 8   3315401  3.304694  101.591944   33.07   34.30    34.80   35.30
# 9   3017445  3.014500  101.718667   36.34   38.50    39.00   40.00
# 10  3016402  3.096528  101.634389   17.03   21.00    21.50   22.00
# 11  3015436  3.019528  101.597417    5.27    9.00     9.50   10.00
# 12  3115403  3.112278  101.596444   14.73   17.00    17.50   18.00
# 13  3115404  3.150056  101.540944   15.18   16.40    16.90   17.40
# 14  3015490  3.096944  101.554167    0.15    7.30     7.80    8.30
# 15  3015435  3.075611  101.553889    2.64    4.50     5.00    6.00
# 16  3015432  3.037722  101.534500    2.84    4.40     4.70    5.00
# 17  3014401  3.048056  101.444806    2.13    2.40     2.70    3.00
# 18  3218401  3.209639  101.875861  131.65  133.40   133.90  134.40
# 19  2917401  2.994444  101.786111   22.47   24.40    25.40   26.40
# 20  3018401  3.013444  101.866056   48.41   48.80    49.80   50.30
# 21  2918401  2.915278  101.823611   20.71   24.00    24.50   25.60
# 22  2717401  2.788667  101.741972    6.96    8.20     8.70    9.20
# 23  2816441  2.992778  101.786944    4.13    6.40     6.90    7.50
# 24  2816443  2.813472  101.641917    2.60    3.30     3.80    4.20
#
#                                                  icon
# 0   http://maps.google.com/mapfiles/ms/icons/green...
# 1   http://maps.google.com/mapfiles/ms/icons/green...
# 2   http://maps.google.com/mapfiles/ms/icons/green...
# 3   http://maps.google.com/mapfiles/ms/icons/green...
# 4   http://maps.google.com/mapfiles/ms/icons/green...
# 5   http://maps.google.com/mapfiles/ms/icons/green...
# 6   http://maps.google.com/mapfiles/ms/icons/green...
# 7   http://maps.google.com/mapfiles/ms/icons/green...
# 8   http://maps.google.com/mapfiles/ms/icons/green...
# 9   http://maps.google.com/mapfiles/ms/icons/green...
# 10  http://maps.google.com/mapfiles/ms/icons/green...
# 11  http://maps.google.com/mapfiles/ms/icons/green...
# 12  http://maps.google.com/mapfiles/ms/icons/green...
# 13  http://maps.google.com/mapfiles/ms/icons/green...
# 14  http://maps.google.com/mapfiles/ms/icons/green...
# 15  http://maps.google.com/mapfiles/ms/icons/green...
# 16  http://maps.google.com/mapfiles/ms/icons/green...
# 17  http://maps.google.com/mapfiles/ms/icons/green...
# 18  http://maps.google.com/mapfiles/ms/icons/green...
# 19  http://maps.google.com/mapfiles/ms/icons/green...
# 20  http://maps.google.com/mapfiles/ms/icons/green...
# 21  http://maps.google.com/mapfiles/ms/icons/green...
# 22  http://maps.google.com/mapfiles/ms/icons/green...
# 23  http://maps.google.com/mapfiles/ms/icons/green...
# 24  http://maps.google.com/mapfiles/ms/icons/green...

# %%
df2 = df[['latitude','longitude','name','info','icon']]

# %%
df2
# Out:
#     latitude   longitude    name     info  \
# 0   3.541417  101.662333   50.49  3516424
# 1   3.469917  101.639806   32.50  3416403
# 2   3.856556  100.895833    0.26  3808401
# 3   3.402778  101.443056    6.10  3414421
# 4   3.371917  101.370500    2.08  3313445
# 5   3.342528  101.269111    2.02  3312446
# 6   3.246139  101.469694    4.53  3214401
# 7   3.306722  101.386444    3.06  3313470
# 8   3.304694  101.591944   33.07  3315401
# 9   3.014500  101.718667   36.34  3017445
# 10  3.096528  101.634389   17.03  3016402
# 11  3.019528  101.597417    5.27  3015436
# 12  3.112278  101.596444   14.73  3115403
# 13  3.150056  101.540944   15.18  3115404
# 14  3.096944  101.554167    0.15  3015490
# 15  3.075611  101.553889    2.64  3015435
# 16  3.037722  101.534500    2.84  3015432
# 17  3.048056  101.444806    2.13  3014401
# 18  3.209639  101.875861  131.65  3218401
# 19  2.994444  101.786111   22.47  2917401
# 20  3.013444  101.866056   48.41  3018401
# 21  2.915278  101.823611   20.71  2918401
# 22  2.788667  101.741972    6.96  2717401
# 23  2.992778  101.786944    4.13  2816441
# 24  2.813472  101.641917    2.60  2816443
#
#                                                  icon
# 0   http://maps.google.com/mapfiles/ms/icons/green...
# 1   http://maps.google.com/mapfiles/ms/icons/green...
# 2   http://maps.google.com/mapfiles/ms/icons/green...
# 3   http://maps.google.com/mapfiles/ms/icons/green...
# 4   http://maps.google.com/mapfiles/ms/icons/green...
# 5   http://maps.google.com/mapfiles/ms/icons/green...
# 6   http://maps.google.com/mapfiles/ms/icons/green...
# 7   http://maps.google.com/mapfiles/ms/icons/green...
# 8   http://maps.google.com/mapfiles/ms/icons/green...
# 9   http://maps.google.com/mapfiles/ms/icons/green...
# 10  http://maps.google.com/mapfiles/ms/icons/green...
# 11  http://maps.google.com/mapfiles/ms/icons/green...
# 12  http://maps.google.com/mapfiles/ms/icons/green...
# 13  http://maps.google.com/mapfiles/ms/icons/green...
# 14  http://maps.google.com/mapfiles/ms/icons/green...
# 15  http://maps.google.com/mapfiles/ms/icons/green...
# 16  http://maps.google.com/mapfiles/ms/icons/green...
# 17  http://maps.google.com/mapfiles/ms/icons/green...
# 18  http://maps.google.com/mapfiles/ms/icons/green...
# 19  http://maps.google.com/mapfiles/ms/icons/green...
# 20  http://maps.google.com/mapfiles/ms/icons/green...
# 21  http://maps.google.com/mapfiles/ms/icons/green...
# 22  http://maps.google.com/mapfiles/ms/icons/green...
# 23  http://maps.google.com/mapfiles/ms/icons/green...
# 24  http://maps.google.com/mapfiles/ms/icons/green...

# %%
from sqlalchemy import create_engine


con = MySQLdb.connect(user='root', password='',host='localhost', database='website_myflood')
engine = create_engine("mysql+pymysql://root:@localhost/website_myflood")
df2.to_sql('locations', con = engine, if_exists='replace',index=False)
# Out:
# 25
